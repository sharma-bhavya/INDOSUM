# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/abstract/abs.csv
# /kaggle/input/abstract/predictions.csv

# %%
abst = pd.read_csv('/kaggle/input/abstract/abs.csv') 
abst
# Out:
#       Unnamed: 0                                            Article  \
# 0              0  Fear shakes Mexico border city after violence ...
# 1              1  Indian-origin boy finds millions of years old ...
# 2              2  Representative ImageA 38-year-old Indian man h...
# 3              3  Residents get tested during their stay at a te...
# 4              4  Israeli PM Benjamin Netanyahu flew to Saudi Ar...
# ...          ...                                                ...
# 4482        4482  FILE - Tanks storing treated radioactive water...
# 4483        4483  Villagers clear debris caused by an earthquake...
# 4484        4484  Seif al-Islam, the son and one-time heir appar...
# 4485        4485  Thai BoysMost members of the Thai youth footba...
# 4486        4486  Karachi to award citizens who identify people ...
#
#                                               Reference  \
# 0     The attacks took place in several neighborhood...
# ...

# %%
# !pip install -q evaluate
# !pip install -q rouge_score

# %%
import evaluate
rouge = evaluate.load('rouge')
predictions = [i for i in abst['+Abs']]
references =  [i for i in abst['Reference']]
results = rouge.compute(predictions=predictions, references=references)
print(results)
# Out:
# {'rouge1': 0.4434958218079821, 'rouge2': 0.3264861341168247, 'rougeL': 0.4005436560757175, 'rougeLsum': 0.40025381269727767}

# %%
predictions = [i for i in abst['Bert']]
references =  [i for i in abst['Reference']]
results = rouge.compute(predictions=predictions, references=references)
print(results)
# Out:
# {'rouge1': 0.32643174565339406, 'rouge2': 0.27188872959856236, 'rougeL': 0.2979175164024788, 'rougeLsum': 0.30425270902299073}

# %%
t5 = pd.read_csv('/kaggle/input/abstract/predictions.csv')
t5
# Out:
#       Unnamed: 0                                     Generated Text  \
# 0              0  fear has invaded the Mexican border city of Re...
# 1              1  Siddak Singh Jhamat, known as Sid, was using a...
# 2              2  28-year-old Indian man has been charged with c...
# 3              3  Symptomatic cases fell 26.7 per cent to 1,931,...
# 4              4  Israeli media reported Monday that Prime Minis...
# ...          ...                                                ...
# 4482        4482  plan was submitted by the Tokyo Electric Power...
# 4483        4483  magnitude 6.4 earthquake early Sunday killed 1...
# 4484        4484  son and one-time heir apparent of late Libyan ...
# 4485        4485  Thai officials said the boys will start the pr...
# 4486        4486  government of Pakistan's Sindh province has de...
#
#                                             Actual Text
# 0     The attacks took place in several neighborhood...
# ...

# %%
predictions = [i for i in t5['Generated Text']]
references =  [i for i in t5['Actual Text']]
results = rouge.compute(predictions=predictions, references=references)
print(results)
# Out:
# {'rouge1': 0.4715243524565509, 'rouge2': 0.3579669711667547, 'rougeL': 0.42850193621810206, 'rougeLsum': 0.4279450952008718}
